# %%
# std
import os
import sys
import inspect
import time
import pathlib
import glob
from math import sqrt
from math import log2
# packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
# %matplotlib inline

# packages
from matplotlib.colors import ListedColormap

# %%
def print_styling(figsize=(10,8)):
    plt.rc('figure', figsize=figsize) 
    plt.style.use("seaborn")
    sns.set_palette("dark")
    SMALL_SIZE = 15
    MEDIUM_SIZE = 18
    BIGGER_SIZE = 26

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('lines', linewidth=2)

    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def plot_CV_with_Std(df, x, y, lable, xlable = "time", ylable = "time", titel = "R2-Score", SaveName = False, ax=None):
    if ax==None:
        ax = plt.gca()
    plt.sca(ax)

    plt.plot(df[x], df[y], '-', label = lable)

    plt.grid(True)
    plt.legend()
    plt.xlabel(xlable)
    plt.ylabel(ylable)
    plt.suptitle(titel)
    #plt.ylabel(y)
    if SaveName:
        plt.savefig(SaveName)

# %%
df_results_MNIST = pd.read_csv("out/Results_MNIST.csv")
df_results_FASION = pd.read_csv("out/Results_FASION.csv")
print(df_results_MNIST.head())
# Out:
#    epoch  accuracy  efficience   epochtime  inference_time  total_Memory
# 0      1     98.45    1.034268   95.188126       87.901261     67.292969
# 1      2     98.58    0.975491  101.056755       93.840085     37.886719
# 2      3     98.83    0.977051  101.151339       93.432738     37.886719
# 3      4     99.00    0.933911  106.005783       97.960213     43.210938
# 4      5     99.05    0.965513  102.587990       94.356074     37.855469

# %%
mpl.style.use('seaborn')
plt.figure(figsize=(10,8))
print_styling()
plot_CV_with_Std(df_results_MNIST,"epoch","accuracy","MNIST",xlable = "epoch",ylable = "accuracy", SaveName = "out/MNIST_accuracy", titel = "Accuracy")
plot_CV_with_Std(df_results_FASION,"epoch","accuracy","FASHION",xlable = "epoch",ylable = "accuracy", SaveName = "out/MNIST_accuracy", titel = "Accuracy")

# %%
mpl.style.use('seaborn')
plt.figure(figsize=(10,8))
print_styling()
plot_CV_with_Std(df_results_MNIST,"epoch","efficience","MNIST",xlable = "epoch",ylable = "efficience", SaveName = "out/MNIST_efficience", titel = "Efficience")
plot_CV_with_Std(df_results_FASION,"epoch","efficience","FASHION",xlable = "epoch",ylable = "efficience", SaveName = "out/MNIST_efficience", titel = "Efficience")

# %%
mpl.style.use('seaborn')
plt.figure(figsize=(10,8))
print_styling()
plot_CV_with_Std(df_results_MNIST,"epoch","inference_time","MNIST",xlable = "epoch",ylable = "inference_time", SaveName = "out/MNIST_inference_time", titel = "Inference_time")
plot_CV_with_Std(df_results_FASION,"epoch","inference_time","FASHION",xlable = "epoch",ylable = "inference_time[s]", SaveName = "out/MNIST_inference_time", titel = "Inference_time")

# %%
mpl.style.use('seaborn')
plt.figure(figsize=(10,8))
print_styling()
plot_CV_with_Std(df_results_MNIST,"epoch","total_Memory","MNIST",xlable = "epoch",ylable = "total_Memory", SaveName = "out/MNIST_total_Memory", titel = "total_Memory")
plot_CV_with_Std(df_results_FASION,"epoch","total_Memory","FASHION",xlable = "epoch",ylable = "total_Memory[Mb]", SaveName = "out/MNIST_total_Memory", titel = "total_Memory")
